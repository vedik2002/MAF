# %%
import pandas as pd

# %%
data = pd.read_json('../../Data/Text/train_data_final_plain.json')
data = data.T
data.head()
# Out:
#                     episode_name target_speaker  \
# 1          32-Maya and her maids        VITTHAL
# 2             38-Sibling Rivalry         ROSESH
# 3           70-Crystal Ball Time          SAHIL
# 4           70-Crystal Ball Time           MAYA
# 5  21-Sahil meets Monisha Part 2   INDRAVARDHAN
#
#                                     target_utterance  \
# 1  aur jab aap apni girlfriend ko Chori chupi Gha...
# 2                         Thanks! dad ke replacement
# 3  I'll tell you... Tumhaari kavita mein ek to, 1...
# 4  Padmaavati ka short from to Paddy hona chaahiy...
# 5   yaani maya acha behave kar rahi hai tch strange!
#
#              context_speakers  \
# 1         [VITTHAL, RADHABAI]
# 2        [SAHIL, MAYA, SAHIL]
# 3      [INDRAVARDHAN, ROSESH]
# 4  [DUSHYANT, MAYA, DUSHYANT]
# 5                    [ROSESH]
#
#                                   context_utterances  \
# 1  [Are aajkal to Chhoti Chhoti Baton per gussa k...
# ...

# %%
data.loc[[2]]["english_explanation"]
# Out:
# 2    Rosesh mocks sahil for making fun of him
# Name: english_explanation, dtype: object
